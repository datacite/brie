# %%
load("../data/17072017_Mugging_Crossref_Datacite_links_out.Rda")

# %%
library('ggplot2')
library('dplyr')
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
head(data)
summary(data)
# Out:
#   license
# 1 https://doi.org/10.13003/CED-terms-of-use
# 2 https://doi.org/10.13003/CED-terms-of-use
# 3 https://doi.org/10.13003/CED-terms-of-use
# 4 https://doi.org/10.13003/CED-terms-of-use
# 5 https://doi.org/10.13003/CED-terms-of-use
# 6 https://doi.org/10.13003/CED-terms-of-use
#   obj_id
# 1 https://doi.org/10.13140/RG.2.1.1350.3122
# 2 https://doi.org/10.5061/dryad.dk385
# 3 https://doi.org/10.7930/J0H12ZXG
# 4 https://doi.org/10.5195/errs.2012.125
# 5 https://doi.org/10.5256/f1000research.10763.d151064
# 6 https://doi.org/10.5281/zenodo.193080
#   source_token                         occurred_at
# 1 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2017-04-01
# 2 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2017-02-13
# 3 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2017-02-13
# 4 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2016-11-21
# 5 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2017-02-10
# 6 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2016-12-20
#   subj_id
# 1 https://doi.org/10.1109/LRA.2017.2651945
# 2 https://doi.org/10.1111/pala.12283
# 3 https://doi.org/10.1007/s10669-017-9631-z
# 4 https://doi.org/10.1080/14702436.2016.1256209
# 5 https://doi.org/10.12688/f1000research.10763.1
# 6 https://doi.org/10.12688/f1000research.10426.1
#   id
# 1 26eb9df3-c841-48c2-b3f8-239c0bf91506
# 2 d53dd280-221e-48f9-bbf8-d48aba12d818
# 3 a750e5b8-3bc6-4054-a321-949c7ad330c5
# 4 f007f43b-7649-4b43-9224-3729b2536f65
# 5 46f3df4f-74c0-42f2-a76d-b108f86d768b
# 6 d871bfce-69ce-4437-be74-b8584ef3b0ec
#   terms                                     message_action source_id timestamp
# 1 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
# 2 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
# 3 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
# 4 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
# 5 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
# 6 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
#   relation_type_id obj_prefix subj_prefix unique(data$obj_prefix)
# 1 references       10.13140   10.1109     10.13140
# 2 references       10.5061    10.1111     10.5061
# 3 references       10.7930    10.1007     10.7930
# 4 references       10.5195    10.1080     10.5195
# 5 references       10.5256    10.12688    10.5256
# 6 references       10.5281    10.12688    10.5281
#   obj_dc                                   unique(data$subj_prefix)
# 1 ResearchGate                             10.1109
# 2 Dryad                                    10.1111
# 3 U.S. Global Change Research Program/UCAR 10.1007
# 4 University of Pittsburgh                 10.1080
# 5 Faculty of 1000 Research Ltd             10.12688
# 6 ZENODO - Research. Shared.               10.12688
#   subj_dc
# 1 Institute of Electrical and Electronics Engineers (IEEE)
# 2 Wiley-Blackwell
# 3 Springer Nature
# 4 Informa UK Limited
# 5 F1000 Research, Ltd.
# 6 F1000 Research, Ltd.
#    license             obj_id          source_token        occurred_at
#  Length:10000       Length:10000       Length:10000       Min.   :1988-06-01
#  Class :character   Class :character   Class :character   1st Qu.:2015-07-04
#  Mode  :character   Mode  :character   Mode  :character   Median :2016-06-14
#                                                           Mean   :2015-12-12
#                                                           3rd Qu.:2017-01-01
#                                                           Max.   :2017-12-15
#
#    subj_id               id               terms           message_action
#  Length:10000       Length:10000       Length:10000       create:10000
#  Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#     source_id       timestamp            relation_type_id  obj_prefix
#  crossref:10000   Min.   :2017-05-19   references:10000   Length:10000
#                   1st Qu.:2017-06-01                      Class :character
#                   Median :2017-06-01                      Mode  :character
#                   Mean   :2017-05-31
#                   3rd Qu.:2017-06-01
#                   Max.   :2017-06-01
#
#  subj_prefix        unique(data$obj_prefix)    obj_dc
#  Length:10000       10.6084 : 605           Length:10000
#  Class :character   10.13140: 603           Class :character
#  Mode  :character   10.5281 : 587           Mode  :character
#                     10.5195 : 546
#                     10.18433: 499
#                     10.5169 : 387
#                     (Other) :6773
#  unique(data$subj_prefix)   subj_dc
#  10.1007 :1945            Length:10000
#  10.1080 :1058            Class :character
#  10.1002 : 749            Mode  :character
#  10.12688: 721
#  10.1088 : 408
#  10.3389 : 406
#  (Other) :4713

# %% [markdown]
# Distribution of events overtime

# %%
data_gr <- data %>% 
    group_by(occurred_at) %>%  
        summarise(total = n())
head(data_gr)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   occurred_at total
# 1 1988-06-01  1
# 2 1988-12-01  1
# 3 1990-12-01  1
# 4 1992-11-01  1
# 5 1994-12-01  1
# 6 1997-06-01  1

# %%
b  <- ggplot(data=data, aes(x=occurred_at)) 
n  <- b + geom_histogram(bins=400)
n + theme(panel.background = element_rect(fill = "white"),
        axis.line = element_line(colour = "grey"),
        axis.title.x = element_text(hjust=1),
        axis.text.x = element_text(angle = 75, hjust = 1),
        axis.title.y = element_text(angle=0, vjust=1))  +
        scale_x_date(date_breaks = "1 year", date_labels =  "%Y") + coord_fixed(ratio=5) +
xlab("Year") +
ylab("No. Links")
# Out:
# plot without title

# %% [markdown]
# Verify old cases of referencing

# %%
head(data[with(data, order(occurred_at)), ])
# Out:
#   license
# 1 https://doi.org/10.13003/CED-terms-of-use
# 2 https://doi.org/10.13003/CED-terms-of-use
# 3 https://doi.org/10.13003/CED-terms-of-use
# 4 https://doi.org/10.13003/CED-terms-of-use
# 5 https://doi.org/10.13003/CED-terms-of-use
# 6 https://doi.org/10.13003/CED-terms-of-use
#   obj_id
# 1 https://doi.org/10.5195/reviberoamer.1985.4008
# 2 https://doi.org/10.5195/REVIBEROAMER.1983.3835
# 3 https://doi.org/10.5195/reviberoamer.1978.3231
# 4 https://doi.org/10.5195/reviberoamer.1982.3735
# 5 https://doi.org/10.5195/reviberoamer.1984.3947
# 6 https://doi.org/10.5195/reviberoamer.1990.4728
#   source_token                         occurred_at
# 1 8676e950-8ac5-4074-8ac3-c0a18ada7e99 1988-06-01
# 2 8676e950-8ac5-4074-8ac3-c0a18ada7e99 1988-12-01
# 3 8676e950-8ac5-4074-8ac3-c0a18ada7e99 1990-12-01
# 4 8676e950-8ac5-4074-8ac3-c0a18ada7e99 1992-11-01
# 5 8676e950-8ac5-4074-8ac3-c0a18ada7e99 1994-12-01
# 6 8676e950-8ac5-4074-8ac3-c0a18ada7e99 1997-06-01
#   subj_id
# 1 https://doi.org/10.1080/00397709.1988.10733647
# 2 https://doi.org/10.1590/S0101-31731988000100010
# 3 https://doi.org/10.1080/00397709.1991.10733720
# 4 https://doi.org/10.1080/13569329209361784
# 5 https://doi.org/10.1080/00397709.1995.10733791
# 6 https://doi.org/10.1080/13569329709361896
#   id
# 1 847904fa-9fb4-47e8-b00c-47ac7b5d922b
# 2 a7d3ea95-d573-415f-84a9-ca8dbd0988e7
# 3 82ca2fdb-504b-4e2d-882a-3c0c4b5da5c3
# 4 6ca23d62-269e-42b9-a74e-8df2750a4445
# 5 858d9373-2ca7-4ee1-9ac7-08b35720990f
# 6 e3749899-8468-4b06-99ff-3094626883ea
#   terms                                     message_action source_id timestamp
# 1 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-06-01
# 2 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-06-01
# 3 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-06-01
# 4 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-06-01
# 5 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-06-01
# 6 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-06-01
#   relation_type_id obj_prefix subj_prefix unique(data$obj_prefix)
# 1 references       10.5195    10.1080     10.5195
# 2 references       10.5195    10.1590     10.5195
# 3 references       10.5195    10.1080     10.5195
# 4 references       10.5195    10.1080     10.5195
# 5 references       10.5195    10.1080     10.5195
# 6 references       10.5195    10.1080     10.5195
#   obj_dc                   unique(data$subj_prefix) subj_dc
# 1 University of Pittsburgh 10.1080                  Informa UK Limited
# 2 University of Pittsburgh 10.1590                  FapUNIFESP (SciELO)
# 3 University of Pittsburgh 10.1080                  Informa UK Limited
# 4 University of Pittsburgh 10.1080                  Informa UK Limited
# 5 University of Pittsburgh 10.1080                  Informa UK Limited
# 6 University of Pittsburgh 10.1080                  Informa UK Limited

# %%
data %>%
    filter(occurred_at <= as.Date("2017-04-01")) %>%
    ggplot(aes(x=occurred_at)) + geom_histogram(bins=500) + theme(panel.background = element_rect(fill = "white"),
            axis.line = element_line(colour = "grey"),
            axis.title.x = element_text(hjust=1),
            axis.text.x = element_text(angle = 75, hjust = 1),
            axis.title.y = element_text(angle=0, vjust=1))  +
            scale_x_date(date_breaks = "1 year", date_labels =  "%Y")  + coord_fixed(ratio=5) +
xlab("Year") +
ylab("No. Links")
# Out:
# plot without title

# %%
data %>%
    filter(occurred_at >= as.Date("2005-04-01") && occurred_at <= as.Date("2017-04-01") ) %>%
    ggplot(aes(x=occurred_at)) + geom_histogram(bins=800) + theme(panel.background = element_rect(fill = "white"),
            axis.line = element_line(colour = "grey"),
            axis.title.x = element_text(hjust=1),
            axis.text.x = element_text(angle = 75, hjust = 1),
            axis.title.y = element_text(angle=0, vjust=1))  +
            scale_x_date(date_breaks = "1 year", date_labels =  "%Y")  + coord_fixed(ratio=5) +
xlab("Year") +
ylab("No. Links")
# Out:
# plot without title

# %%
tail(names(sort(table(data$occurred_at))), 3)
# data %>%
#     filter(occurred_at == as.Date("2016-01-01")  )
# Out:
# [1] "2015-01-01" "2017-01-01" "2016-01-01"

# %%
data_timestamp <- data %>% 
    group_by(timestamp) %>%  
        summarise(total = n()) 
data_timestamp
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   timestamp  total
# 1 2017-05-19   28
# 2 2017-05-31 2167
# 3 2017-06-01 7805

# %%
b  <- ggplot(data) 
n  <- b + geom_bar( aes(timestamp))
n + theme(panel.background = element_rect(fill = "white"),
        axis.line = element_line(colour = "grey"),
        axis.title.x = element_text(hjust=1),
        axis.text.x = element_text(angle = 75, hjust = 1),
        axis.title.y = element_text(angle=0, vjust=1))
# Out:
# plot without title

# %% [markdown]
# These are the Crossref prefixes with most relationships

# %%
data_obj <- data %>% 
    group_by(obj_dc) %>%  
        summarise(total = n())  %>%
    arrange(desc(total))
head(data_obj,25)
nrow(data_obj)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#    obj_dc
# 1  figshare Academic Research System
# 2  ResearchGate
# 3  ZENODO - Research. Shared.
# 4  University of Pittsburgh
# 5  UAlberta JPPS Journal
# 6  E-Periodica
# 7  Dryad
# 8  ICPSR
# 9  German Medical Science
# 10 Faculty of 1000 Research Ltd
# 11 Tabriz University of Medical Sciences
# 12 Dagstuhl
# 13 Oak Ridge National Laboratory Distributed Active Archive Center (ORNL DAAC)
# 14 WIP - Renewable Energies
# 15 PANGAEA - Data Publisher for Earth & Environmental Science
# 16 UAlberta EBLIP Journal
# 17 Eurographics
# 18 GESIS Leibniz Institute for the Social Sciences
# 19 Università degli Studi di Bologna
# 20 PeerJ
# 21 CERN Publishing
# 22 NASA Goddard Space Flight Center (GSFC)
# 23 National Center for Atmospheric Research (NCAR)
# 24 Universität Bielefeld
# 25 U.S. Global Change Research Program/UCAR
#    total
# 1  605
# 2  603
# 3  587
# 4  546
# 5  499
# 6  387
# 7  386
# 8  308
# 9  275
# 10 274
# 11 269
# 12 261
# 13 244
# 14 240
# 15 237
# 16 230
# 17 215
# 18 180
# 19 148
# 20 136
# 21 125
# 22 118
# 23 118
# 24 115
# 25 106
# [1] 280

# %%
data_obj <- data %>% 
    group_by(obj_prefix) %>%  
        summarise(total = n())  %>%
    arrange(desc(total))
head(data_obj)
nrow(data_obj)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   obj_prefix total
# 1 10.6084    605
# 2 10.13140   603
# 3 10.5281    587
# 4 10.5195    546
# 5 10.18433   499
# 6 10.5169    387
# [1] 302

# %% [markdown]
# These are the DataCite prefixes with most relationships

# %%
data_subj <- data %>% 
    group_by(subj_dc) %>%  
        summarise(total = n())  %>%
    arrange(desc(total))
head(data_subj,40)
nrow(data_subj)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#    subj_dc                                                  total
# 1  Springer Nature                                          2343
# 2  Wiley-Blackwell                                          1141
# 3  Informa UK Limited                                       1063
# 4  F1000 Research, Ltd.                                      721
# 5  IOP Publishing                                            413
# 6  Frontiers Media SA                                        406
# 7  SAGE Publications                                         294
# 8  MDPI AG                                                   265
# 9  American Chemical Society (ACS)                           262
# 10 Open Publishing Association                               230
# 11 Emerald                                                   226
# 12 Hindawi Limited                                           222
# 13 Pensoft Publishers                                        185
# 14 Japan Society of Applied Physics                          181
# 15 American Physical Society (APS)                           176
# 16 PeerJ                                                     160
# 17 Elsevier BV                                               140
# 18 AIP Publishing                                            132
# 19 eLife Sciences Organisation, Ltd.                         127
# 20 FapUNIFESP (SciELO)                                        85
# 21 Kowsar Medical Institute                                   73
# 22 OpenEdition                                                68
# 23 Walter de Gruyter GmbH                                     63
# 24 Royal Society of Chemistry (RSC)                           60
# 25 Mathematical Sciences Publishers                           51
# 26 Canadian Science Publishing                                48
# 27 Faculty of 1000, Ltd.                                      48
# 28 Franco Angeli                                              45
# 29 Inter-Research Science Center                              39
# 30 Informa Healthcare                                         38
# 31 Institute of Electrical and Electronics Engineers (IEEE)   37
# 32 JMIR Publications Inc.                                     35
# 33 Society of Rheology                                        34
# 34 Scientific Research Publishing, Inc,                       31
# 35 American Society for Microbiology                          29
# 36 Morgan & Claypool Publishers LLC                           29
# 37 International Neuroscience Institute                       23
# 38 Copernicus GmbH                                            21
# 39 Future Medicine Ltd                                        21
# 40 American Astronomical Society                              20
# [1] 155

# %%
data_subj <- data %>% 
    group_by(subj_prefix) %>%  
        summarise(total = n())  %>%
    arrange(desc(total))
head(data_subj)
nrow(data_subj)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   subj_prefix total
# 1 10.1007     1945
# 2 10.1080     1058
# 3 10.1002      749
# 4 10.12688     721
# 5 10.1088      408
# 6 10.3389      406
# [1] 171

# %% [markdown]
# These are the most frequent Crossref to DataCite relationships

# %%
data_comp_dc <- data %>% 
    group_by(obj_dc, subj_dc) %>%  
        summarise(total = n())  %>%
        arrange(desc(total))
head(data_comp_dc,10)
nrow(data_comp_dc)
data_comp_dc$obj_dc <- as.factor(data_comp_dc$obj_dc)
data_comp_dc$subj_dc <- as.factor(data_comp_dc$subj_dc)
dataxx = data_comp_dc %>% select(subj_dc, obj_dc, total)
head(dataxx,50)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#    obj_dc                            subj_dc                          total
# 1  figshare Academic Research System F1000 Research, Ltd.             371
# 2  Faculty of 1000 Research Ltd      F1000 Research, Ltd.             268
# 3  ResearchGate                      Springer Nature                  253
# 4  Dagstuhl                          Open Publishing Association      200
# 5  University of Pittsburgh          Informa UK Limited               197
# 6  Dryad                             Wiley-Blackwell                  189
# 7  WIP - Renewable Energies          Japan Society of Applied Physics 177
# 8  UAlberta EBLIP Journal            Emerald                          161
# 9  ZENODO - Research. Shared.        Springer Nature                  139
# 10 ZENODO - Research. Shared.        Pensoft Publishers               128
# [1] 1332
#    subj_dc
# 1  F1000 Research, Ltd.
# 2  F1000 Research, Ltd.
# 3  Springer Nature
# 4  Open Publishing Association
# 5  Informa UK Limited
# 6  Wiley-Blackwell
# 7  Japan Society of Applied Physics
# 8  Emerald
# 9  Springer Nature
# 10 Pensoft Publishers
# 11 American Physical Society (APS)
# 12 Informa UK Limited
# 13 Wiley-Blackwell
# 14 SAGE Publications
# 15 Springer Nature
# 16 Informa UK Limited
# 17 Elsevier BV
# 18 eLife Sciences Organisation, Ltd.
# 19 Springer Nature
# 20 IOP Publishing
# 21 Informa UK Limited
# 22 Wiley-Blackwell
# 23 Wiley-Blackwell
# 24 Springer Nature
# 25 Springer Nature
# 26 Springer Nature
# 27 American Chemical Society (ACS)
# 28 Kowsar Medical Institute
# 29 Springer Nature
# 30 Springer Nature
# 31 Wiley-Blackwell
# 32 Springer Nature
# 33 Springer Nature
# 34 Hindawi Limited
# 35 AIP Publishing
# 36 Springer Nature
# 37 F1000 Research, Ltd.
# 38 Wiley-Blackwell
# 39 Springer Nature
# 40 Wiley-Blackwell
# 41 Faculty of 1000, Ltd.
# 42 Springer Nature
# 43 Informa UK Limited
# 44 PeerJ
# 45 FapUNIFESP (SciELO)
# 46 Springer Nature
# 47 Springer Nature
# 48 Informa UK Limited
# 49 OpenEdition
# 50 Springer Nature
#    obj_dc
# 1  figshare Academic Research System
# 2  Faculty of 1000 Research Ltd
# 3  ResearchGate
# 4  Dagstuhl
# 5  University of Pittsburgh
# 6  Dryad
# 7  WIP - Renewable Energies
# 8  UAlberta EBLIP Journal
# 9  ZENODO - Research. Shared.
# 10 ZENODO - Research. Shared.
# 11 E-Periodica
# 12 ICPSR
# 13 Oak Ridge National Laboratory Distributed Active Archive Center (ORNL DAAC)
# 14 ICPSR
# 15 PANGAEA - Data Publisher for Earth & Environmental Science
# 16 ResearchGate
# 17 UAlberta JPPS Journal
# 18 Dryad
# 19 German Medical Science
# 20 CERN Publishing
# 21 UAlberta JPPS Journal
# 22 Eurographics
# 23 NASA Goddard Space Flight Center (GSFC)
# 24 Eurographics
# 25 GESIS Leibniz Institute for the Social Sciences
# 26 UAlberta JPPS Journal
# 27 ZENODO - Research. Shared.
# 28 Tabriz University of Medical Sciences
# 29 Dryad
# 30 National Center for Atmospheric Research (NCAR)
# 31 PANGAEA - Data Publisher for Earth & Environmental Science
# 32 E-Periodica
# 33 Università degli Studi di Bologna
# 34 Tabriz University of Medical Sciences
# 35 E-Periodica
# 36 Oak Ridge National Laboratory Distributed Active Archive Center (ORNL DAAC)
# 37 ZENODO - Research. Shared.
# 38 ResearchGate
# 39 ICPSR
# 40 Interdisciplinary Earth Data Alliance
# 41 figshare Academic Research System
# 42 figshare Academic Research System
# 43 GESIS Leibniz Institute for the Social Sciences
# 44 PeerJ
# 45 University of Pittsburgh
# 46 University of Pittsburgh
# 47 Tabriz University of Medical Sciences
# 48 UCSB
# 49 University of Pittsburgh
# 50 Dagstuhl
#    total
# 1  371
# 2  268
# 3  253
# 4  200
# 5  197
# 6  189
# 7  177
# 8  161
# 9  139
# 10 128
# 11 116
# 12 110
# 13 108
# 14 102
# 15  96
# 16  94
# 17  91
# 18  90
# 19  88
# 20  84
# 21  82
# 22  76
# 23  74
# 24  70
# 25  67
# 26  67
# 27  63
# 28  62
# 29  61
# 30  61
# 31  60
# 32  59
# 33  58
# 34  55
# 35  54
# 36  53
# 37  53
# 38  52
# 39  50
# 40  50
# 41  48
# 42  48
# 43  48
# 44  47
# 45  47
# 46  46
# 47  45
# 48  44
# 49  44
# 50  43

# %%
unlist(lapply(data_comp_dc, function(x) any(is.na(x))))
# Out:
#  obj_dc subj_dc   total
#   FALSE   FALSE   FALSE

# %%
data_comp_px <- data %>% 
    group_by(obj_prefix, subj_prefix) %>%  
        summarise(total = n())  %>%
        arrange(desc(total))
head(data_comp_px)
nrow(data_comp_px)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   obj_prefix subj_prefix total
# 1 10.6084    10.12688    371
# 2 10.5256    10.12688    256
# 3 10.13140   10.1007     224
# 4 10.4230    10.4204     200
# 5 10.5195    10.1080     197
# 6 10.4229    10.7567     177
# [1] 1513

# %%
parallelset <- function(..., freq, col="gray", border=0, layer, 
                             alpha=0.5, gap.width=0.05) {
  p <- data.frame(..., freq, col, border, alpha, stringsAsFactors=FALSE)
  n <- nrow(p)
  if(missing(layer)) { layer <- 1:n }
  p$layer <- layer
  np <- ncol(p) - 5
  d <- p[ , 1:np, drop=FALSE]
  p <- p[ , -c(1:np), drop=FALSE]
  p$freq <- with(p, freq/sum(freq))
  col <- col2rgb(p$col, alpha=TRUE)
  if(!identical(alpha, FALSE)) { col["alpha", ] <- p$alpha*256 }
  p$col <- apply(col, 2, function(x) do.call(rgb, c(as.list(x), maxColorValue = 256)))
  getp <- function(i, d, f, w=gap.width) {
    a <- c(i, (1:ncol(d))[-i])
    o <- do.call(order, d[a])
    x <- c(0, cumsum(f[o])) * (1-w)
    x <- cbind(x[-length(x)], x[-1])
    gap <- cumsum( c(0L, diff(as.numeric(d[o,i])) != 0) )
    gap <- gap / max(gap) * w
    (x + gap)[order(o),]
  }
  dd <- lapply(seq_along(d), getp, d=d, f=p$freq)
  par(mar = c(0, 0, 2, 0) + 0.1, xpd=TRUE )
  plot(NULL, type="n",xlim=c(0, 1), ylim=c(np, 1),
       xaxt="n", yaxt="n", xaxs="i", yaxs="i", xlab='', ylab='', frame=FALSE)
  for(i in rev(order(p$layer)) ) {
     for(j in 1:(np-1) )
     polygon(c(dd[[j]][i,], rev(dd[[j+1]][i,])), c(j, j, j+1, j+1),
             col=p$col[i], border=p$border[i])
   }
   text(0, seq_along(dd), labels=names(d), adj=c(0,-2), font=2)
   for(j in seq_along(dd)) {
     ax <- lapply(split(dd[[j]], d[,j]), range)
     for(k in seq_along(ax)) {
       lines(ax[[k]], c(j, j))
#          text(ax[[k]][1], j, labels=names(ax)[k], adj=c(0, -0.25))
     }
   }           
}

# %%
library(RColorBrewer)
darkcols <- brewer.pal(8, "Spectral")
pal <-colorRampPalette(brewer.pal(8, "Paired"))
pal
# Out:
# function (n)
# {
#     x <- ramp(seq.int(0, 1, length.out = n))
#     if (ncol(x) == 4L)
#         rgb(x[, 1L], x[, 2L], x[, 3L], x[, 4L], maxColorValue = 255)
#     else rgb(x[, 1L], x[, 2L], x[, 3L], maxColorValue = 255)
# }
# <bytecode: 0x42e5ef0>
# <environment: 0x42e4d28>

# %%
with(data_comp_dc, parallelset(obj_dc, subj_dc,  freq=total))
# Out:
# plot without title

# %%
with(data_comp_px, parallelset(obj_prefix, subj_prefix,  freq=total))
# Out:
# plot without title

# %% [markdown]
# Looking at DataCite Only Type

# %%
load("../data/17072017_Mugging_Crossref_Datacite_links_dcDois_out.Rda")

# %%
# summ
types<-data.frame(summ)
types$types<-rownames(types)
rownames(types) <- NULL
types<-types %>%
 mutate( perc = round((summ/7564),4)*100)
types<-(types[with(types, order(-summ)), ])
types
# yyy<-data.frame(round((types$summ/7564),4)*100)
# # colnames(yyy) <- c("counts")
# # yyy<-(yyy[with(yyy, order(-counts)), ])
# yyy
# Out:
#    summ types                perc
# 3  2988 text                 39.50
# 1  1777 dataset              23.49
# 2   272 collection            3.60
# 4   246 software              3.25
# 8    40 other                 0.53
# 9    23 workflow              0.30
# 6    21 image                 0.28
# 5    10 audiovisual           0.13
# 7     3 interactive-resource  0.04
# 10    1 physical-object       0.01
# 11    1 model                 0.01

# %%
g<- ggplot(types,aes(0, summ, fill = as.factor(types))) + geom_bar(stat = "identity") 
g + theme(panel.background = element_rect(fill = "white"),
            axis.line = element_line(colour = "grey"),
            axis.title.x = element_text(hjust=1),
            axis.text.x = element_text(angle = 75, hjust = 1),
            axis.title.y = element_text(angle=0, vjust=1))  + scale_fill_grey(start = 1, end = 0.15)
# Out:
# plot without title

# %%
load("../data/17072017_Mugging_Crossref_Datacite_links_typeDois_out.Rda")

# %%
nrow(data_doix)
# Out:
# [1] 10217

# %%
g<- ggplot(data_doix, aes(`resource-type-id`)) + geom_bar() 
# g + theme(panel.background = element_rect(fill = "white"),
#             axis.line = element_line(colour = "grey"),
#             axis.title.x = element_text(hjust=1),
#             axis.text.x = element_text(angle = 75, hjust = 1),
#             axis.title.y = element_text(angle=0, vjust=1))  + scale_fill_grey(start = 1, end = 0.15) 
g
# Out:
# plot without title
