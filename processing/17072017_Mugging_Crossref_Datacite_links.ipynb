# %%
install.packages("rdatacite")

# %%
library(jsonlite)
library(dplyr)
library(stringr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
rows<-9000

# http://query.eventdata.crossref.org/events?rows=10000&cursor=17399fd9-319d-4b28-9727-887264a632b1
jsondf<-fromJSON(paste0('http://query.eventdata.crossref.org/events?rows=',rows,'&filter=source:crossref'))
# Out:
# Error in open.connection(con, "rb"): HTTP error 500.
# Traceback:
#
# 1. fromJSON(paste0("http://query.eventdata.crossref.org/events?rows=",
#  .     rows, "&filter=source:crossref"))
# 2. fromJSON_string(txt = txt, simplifyVector = simplifyVector, simplifyDataFrame = simplifyDataFrame,
#  .     simplifyMatrix = simplifyMatrix, flatten = flatten, ...)
# 3. parseJSON(txt, bigint_as_char)
# 4. parse_con(txt, 1024^2, bigint_as_char)
# 5. open(con, "rb")
# 6. open.connection(con, "rb")

# %%
data<-jsondf$message$events
nrow(data)
# Out:
# [1] 10000

# %%
get_dcdatacentre<- function(obj_id){
    doi<-str_extract(obj_id,'(10\\.\\d{4,5}\\/.+)\\z')
    dc_info<-fromJSON(paste0('https://api.datacite.org/works?query=',doi,'&rows=0'))
    return(head(dc_info$meta$`data-centers`,1)$title)
}

# %%
data <- data %>% 
    mutate(occurred_at = as.Date(occurred_at),
           timestamp = as.Date(timestamp),
           relation_type_id = as.factor(relation_type_id),
           message_action = as.factor(message_action),
           obj_prefix = str_extract(obj_id,'(10\\.\\d{4,5})'),
           subj_prefix = str_extract(subj_id,'(10\\.\\d{4,5})'),
           obj_dc = get_dcdatacentre(obj_id),
           message_action = as.factor(message_action),
           source_id = as.factor(source_id))

# %%
nrow(data)
# Out:
# [1] 10000

# %%
save(data,file="../data/05072017_Mugging_Crossref_Datacite_links_out.Rda")

# %%
# Out:
# [1] "10.5061"

# %% [markdown]
# Adding Datcentre
#
# https://api.datacite.org/works?query=prefix:10.5256&rows=1

# %%
doi<-str_extract(data$obj_id[1],'(10\\.\\d{4,5}\\/.+)\\z')
doi
# Out:
# [1] "10.13140/RG.2.1.1350.3122"

# %%
dc_info<-fromJSON(paste0('https://api.datacite.org/works?query=',doi,'&rows=0'))
dc_info
# Out:
# $data
# list()
#
# $meta
# $meta$`resource-types`
# list()
#
# $meta$years
#     id title count
# 1 2015  2015     1
#
# $meta$`data-centers`
#      id        title count
# 1 rg.rg ResearchGate     1
#
# $meta$`schema-versions`
#   id    title count
# 1  3 Schema 3     1
#
# $meta$total
# [1] 1

# %%
dc_search(q = doi, fl = c('datacentre'))$datacentre
# Out:
# https://search.datacite.org/api?q=10.13140/RG.2.1.1350.3122&fl=datacentre&wt=json
# [1] "RG.RG - ResearchGate"

# %%
head(dc_info$meta$`data-centers`,1)$title
# Out:
# [1] "ResearchGate"

# %%
get_dcdatacentre("https://doi.org/10.5256/f1000research.10763.d151064")
# Out:
# [1] "Faculty of 1000 Research Ltd"

# %%
load('../data/05072017_Mugging_Crossref_Datacite_links_out.Rda')

# %%
data
# Out:
#       license
# 1     https://doi.org/10.13003/CED-terms-of-use
# 2     https://doi.org/10.13003/CED-terms-of-use
# 3     https://doi.org/10.13003/CED-terms-of-use
https://doi.org/10.13003/CED-terms-of-use create         crossref
# 9999  https://doi.org/10.13003/CED-terms-of-use create         crossref
# 10000 https://doi.org/10.13003/CED-terms-of-use create         crossref
#       timestamp  relation_type_id obj_prefix subj_prefix
# 1     2017-05-19 references       10.13140   10.1109
# 2     2017-05-19 references       10.5061    10.1111
# 3     2017-05-19 references       10.7930    10.1007
# 4     2017-05-19 references       10.5195    10.1080
# 5     2017-05-19 references       10.5256    10.12688
# 6     2017-05-19 references       10.5281    10.12688
# 7     2017-05-19 references       10.18433   10.3109
# 8     2017-05-19 references       10.5681    10.17795
# 9     2017-05-19 references       10.3886    10.1080
# 10    2017-05-19 references       10.3886    10.1080
# 11    2017-05-19 references       10.5256    10.12688
# 12    2017-05-19 references       10.5281    10.12688
# 13    2017-05-19 references       10.3886    10.1080
# 14    2017-05-19 references       10.5061    10.7554
# 15    2017-05-19 references       10.5061    10.1111
# 16    2017-05-19 references       10.5281    10.12688
# 17    2017-05-19 references       10.5256    10.12688
# 18    2017-05-19 references       10.5281    10.1111
# 19    2017-05-19 references       10.3205    10.1080
# 20    2017-05-19 references       10.5256    10.12688
# 21    2017-05-19 references       10.5256    10.12688
# 22    2017-05-19 references       10.3205    10.1177
# 23    2017-05-19 references       10.7490    10.12688
# 24    2017-05-19 references       10.13140   10.12688
# 25    2017-05-19 references       10.5281    10.12688
# 26    2017-05-19 references       10.5524    10.12688
# 27    2017-05-19 references       10.6084    10.12688
# 28    2017-05-19 references       10.5256    10.12688
# 29    2017-05-31 references       10.4119    10.1108
# 30    2017-05-31 references       10.17863   10.1002
# ⋮     ⋮          ⋮                ⋮          ⋮
# 9971  2017-06-01 references       10.5284    10.1080
# 9972  2017-06-01 references       10.3334    10.1002
# 9973  2017-06-01 references       10.5681    10.1021
# 9974  2017-06-01 references       10.5681    10.15171
# 9975  2017-06-01 references       10.5281    10.1002
# 9976  2017-06-01 references       10.5681    10.15171
# 9977  2017-06-01 references       10.5681    10.17795
# 9978  2017-06-01 references       10.18433   10.15171
# 9979  2017-06-01 references       10.11588   10.3389
# 9980  2017-06-01 references       10.5681    10.5812
# 9981  2017-06-01 references       10.7916    10.5812
# 9982  2017-06-01 references       10.18438   10.1108
# 9983  2017-06-01 references       10.5065    10.5626
# 9984  2017-06-01 references       10.18438   10.15802
# 9985  2017-06-01 references       10.5681    10.15171
# 9986  2017-06-01 references       10.5284    10.1080
# 9987  2017-06-01 references       10.5681    10.1155
# 9988  2017-06-01 references       10.5284    10.1080
# 9989  2017-06-01 references       10.5281    10.1186
# 9990  2017-06-01 references       10.3205    10.3310
# 9991  2017-06-01 references       10.3205    10.1177
# 9992  2017-06-01 references       10.7916    10.1186
# 9993  2017-06-01 references       10.6092    10.3280
# 9994  2017-06-01 references       10.5195    10.1080
# 9995  2017-06-01 references       10.5681    10.15171
# 9996  2017-06-01 references       10.18433   10.3390
# 9997  2017-06-01 references       10.18433   10.1007
# 9998  2017-06-01 references       10.20360   10.1080
# 9999  2017-06-01 references       10.7930    10.1039
# 10000 2017-06-01 references       10.18433   10.1016

# %%
data <- data %>% 
    rowwise() %>% 
    mutate(obj_dc = get_dcdatacentre(obj_id)) 
nrow(data)

# %%
data$obj_id[1]
# Out:
# [1] "https://doi.org/10.13140/RG.2.1.1350.3122"

# %%
get_dcdatacentrebyprefix<- function(obj_prefix){
    dc_info<-fromJSON(paste0('https://api.datacite.org/works?query=',obj_prefix,'&rows=0'))
    return(head(dc_info$meta$`data-centers`,1)$title)
}

get_xrdatacentrebyprefix<- function(subj_prefix){
    dc_info<-fromJSON(paste0('https://api.crossref.org/prefixes/',subj_prefix))
    return(head(dc_info$message$name,1))
}

# %%
get_dcdatacentrebyprefix('10.13140')
# Out:
# [1] "ResearchGate"

# %%
dc_prefixes<-as.data.frame(unique(data$obj_prefix))
dc_prefixes$value<-dc_prefixes$`unique(data$obj_prefix)`
colnames(dc_prefixes)[2] <- "obj_prefix"
# Out:
#     unique(data$obj_prefix) obj_prefix
# 1   10.13140                10.13140
# 2   10.5061                 10.5061
# 3   10.7930                 10.7930
# 4   10.5195                 10.5195
# 5   10.5256                 10.5256
# 6   10.5281                 10.5281
# 7   10.18433                10.18433
# 8   10.5681                 10.5681
# 9   10.3886                 10.3886
# 10  10.3205                 10.3205
# 11  10.7490                 10.7490
# 12  10.5524                 10.5524
# 13  10.6084                 10.6084
# 14  10.4119                 10.4119
# 15  10.17863                10.17863
# 16  10.18162                10.18162
# 17  10.5678                 10.5678
# 18  10.18438                10.18438
# 19  10.5078                 10.5078
# 20  10.5255                 10.5255
# 21  10.5070                 10.5070
# 22  10.1594                 10.1594
# 23  10.5067                 10.5067
# 24  10.7289                 10.7289
# 25  10.5062                 10.5062
# 26  10.7489                 10.7489
# 27  10.5440                 10.5440
# 28  10.7265                 10.7265
# 29  10.3204                 10.3204
# 30  10.6092                 10.6092
# ⋮   ⋮                       ⋮
# 273 10.18740                10.18740
# 274 10.3932                 10.3932
# 275 10.14291                10.14291
# 276 10.21427                10.21427
# 277 10.17616                10.17616
# 278 10.15497                10.15497
# 279 10.17192                10.17192
# 280 10.17888                10.17888
# 281 10.5159                 10.5159
# 282 10.5203                 10.5203
# 283 10.5879                 10.5879
# 284 10.12754                10.12754
# 285 10.17035                10.17035
# 286 10.21425                10.21425
# 287 10.21237                10.21237
# 288 10.7298                 10.7298
# 289 10.18116                10.18116
# 290 10.15142                10.15142
# 291 10.7267                 10.7267
# 292 10.5069                 10.5069
# 293 10.5288                 10.5288
# 294 10.17617                10.17617
# 295 10.17613                10.17613
# 296 10.15463                10.15463
# 297 10.5451                 10.5451
# 298 10.15478                10.15478
# 299 10.13133                10.13133
# 300 10.21334                10.21334
# 301 10.15474                10.15474
# 302 10.15129                10.15129

# %%
dc_prefixes <- dc_prefixes %>% 
    rowwise() %>% 
    mutate(obj_dc = as.factor(get_dcdatacentrebyprefix(obj_prefix)) )
nrow(dc_prefixes)
# Out:
# [1] 10000

# %%
data <- data %>% 
    rowwise() %>% 
    left_join(dc_prefixes)
nrow(data)
# Out:
# Joining, by = "obj_prefix"
# Warning message in left_join_impl(x, y, by$x, by$y, suffix$x, suffix$y):
# “joining factor and character vector, coercing into character vector”
# [1] 10000

# %%
head(data)
# Out:
#   license
# 1 https://doi.org/10.13003/CED-terms-of-use
# 2 https://doi.org/10.13003/CED-terms-of-use
# 3 https://doi.org/10.13003/CED-terms-of-use
# 4 https://doi.org/10.13003/CED-terms-of-use
# 5 https://doi.org/10.13003/CED-terms-of-use
# 6 https://doi.org/10.13003/CED-terms-of-use
#   obj_id
# 1 https://doi.org/10.13140/RG.2.1.1350.3122
# 2 https://doi.org/10.5061/dryad.dk385
# 3 https://doi.org/10.7930/J0H12ZXG
# 4 https://doi.org/10.5195/errs.2012.125
# 5 https://doi.org/10.5256/f1000research.10763.d151064
# 6 https://doi.org/10.5281/zenodo.193080
#   source_token                         occurred_at
# 1 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2017-04-01
# 2 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2017-02-13
# 3 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2017-02-13
# 4 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2016-11-21
# 5 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2017-02-10
# 6 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2016-12-20
#   subj_id
# 1 https://doi.org/10.1109/LRA.2017.2651945
# 2 https://doi.org/10.1111/pala.12283
# 3 https://doi.org/10.1007/s10669-017-9631-z
# 4 https://doi.org/10.1080/14702436.2016.1256209
# 5 https://doi.org/10.12688/f1000research.10763.1
# 6 https://doi.org/10.12688/f1000research.10426.1
#   id
# 1 26eb9df3-c841-48c2-b3f8-239c0bf91506
# 2 d53dd280-221e-48f9-bbf8-d48aba12d818
# 3 a750e5b8-3bc6-4054-a321-949c7ad330c5
# 4 f007f43b-7649-4b43-9224-3729b2536f65
# 5 46f3df4f-74c0-42f2-a76d-b108f86d768b
# 6 d871bfce-69ce-4437-be74-b8584ef3b0ec
#   terms                                     message_action source_id timestamp
# 1 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
# 2 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
# 3 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
# 4 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
# 5 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
# 6 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
#   relation_type_id obj_prefix subj_prefix unique(data$obj_prefix)
# 1 references       10.13140   10.1109     10.13140
# 2 references       10.5061    10.1111     10.5061
# 3 references       10.7930    10.1007     10.7930
# 4 references       10.5195    10.1080     10.5195
# 5 references       10.5256    10.12688    10.5256
# 6 references       10.5281    10.12688    10.5281
#   obj_dc
# 1 ResearchGate
# 2 Dryad
# 3 U.S. Global Change Research Program/UCAR
# 4 University of Pittsburgh
# 5 Faculty of 1000 Research Ltd
# 6 ZENODO - Research. Shared.

# %%
get_xrdatacentrebyprefix('10.1111')
# Out:
# [1] "Wiley-Blackwell"

# %%
xr_prefixes<-as.data.frame(unique(data$subj_prefix))
xr_prefixes$subj_prefix<-xr_prefixes$`unique(data$subj_prefix)`
xr_prefixes <- xr_prefixes %>% 
    rowwise() %>% 
    mutate(subj_dc = as.factor(get_xrdatacentrebyprefix(subj_prefix)))
nrow(dc_prefixes)
# Out:
# [1] 302

# %%
head(xr_prefixes)
# Out:
#   unique(data$subj_prefix) subj_prefix
# 1 10.1109                  10.1109
# 2 10.1111                  10.1111
# 3 10.1007                  10.1007
# 4 10.1080                  10.1080
# 5 10.12688                 10.12688
# 6 10.3109                  10.3109
#   subj_dc
# 1 Institute of Electrical and Electronics Engineers (IEEE)
# 2 Wiley-Blackwell
# 3 Springer Nature
# 4 Informa UK Limited
# 5 F1000 Research, Ltd.
# 6 Informa Healthcare

# %%
data <- data %>% 
    rowwise() %>% 
    left_join(xr_prefixes)
head(data)
# Out:
# Joining, by = "subj_prefix"
# Warning message in left_join_impl(x, y, by$x, by$y, suffix$x, suffix$y):
# “joining factor and character vector, coercing into character vector”
# [1] 10000

# %%
nrow(data)
# Out:
# [1] 10000

# %%
save(data,file="../data/17072017_Mugging_Crossref_Datacite_links_out.Rda")

# %%
https://api.datacite.org/works?ids=
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:7: unexpected '/'
# 1: https:/
#           ^
# Traceback:

# %%
dois='10.13140/RG.2.1.1350.3122,10.7930/J0H12ZXG'
dois_types<-fromJSON(paste0('https://api.datacite.org/works?ids=',dois,'&rows=0'))
dois_types
# Out:
# $data
#                                          id  type            attributes.doi
# 1 https://doi.org/10.13140/RG.2.1.1350.3122 works 10.13140/RG.2.1.1350.3122
# 2          https://doi.org/10.7930/J0H12ZXG works          10.7930/J0H12ZXG
#   attributes.url
# 1             NA
# 2             NA
#                                                                                                                                       attributes.author
# 1                                                                   Kleinhans, Rosman, Michalik, Tripp, Detry, Ashley, Benjamin, Michael, Bryan, Renaud
# 2 Moss, Scarlett, Kenney, Kunreuther, Lempert, Manning, Williams, Boyd, Cloyd, Kaatz, Patton, R., P. L., M. A., H., R., J., B. K., J. W., E. T., L., L.
#                                                                                                                                                   attributes.title
# 1                                             G3DB: A Database of Successful and Failed Grasps with RGB-D Images, Point Clouds, Mesh Models and Gripper Parameters
# 2 Ch. 26: Decision Support: Connecting Science, Risk Perception, and Decisions. Climate Change Impacts in the United States: The Third National Climate Assessment
#            attributes.container-title attributes.description
# 1                         Unpublished
# 2 U.S. Global Change Research Program
#   attributes.resource-type-subtype attributes.data-center-id
# 1                             <NA>                     rg.rg
# 2     Formal scientific assessment                cdl.usgcrp
#   attributes.member-id attributes.resource-type-id attributes.version
# 1                   rg                        <NA>                 NA
# 2                  cdl                        text                 NA
#   attributes.license attributes.schema-version attributes.results
# 1                 NA                         3               NULL
# 2                 NA                       2.2               NULL
#   attributes.related-identifiers attributes.published attributes.deposited
# 1                           NULL                 2015 2016-03-11T07:01:40Z
# 2                           NULL                 2014 2014-05-06T21:40:52Z
#     attributes.updated attributes.media
# 1 2016-03-11T07:01:40Z               NA
# 2 2014-05-06T21:40:52Z               NA
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 attributes.xml
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 2 ...
#
# $meta
# $meta$`resource-types`
#     id title count
# 1 text  Text     1
#
# $meta$years
#     id title count
# 1 2015  2015     1
# 2 2014  2014     1
#
# $meta$`data-centers`
#           id                                    title count
# 1      rg.rg                             ResearchGate     1
# 2 cdl.usgcrp U.S. Global Change Research Program/UCAR     1
#
# $meta$`schema-versions`
#    id      title count
# 1   3   Schema 3     1
# 2 2.2 Schema 2.2     1
#
# $meta$total
# [1] 2

# %%
get_dcdatacentre<- function(obj_id){
    doi<-str_extract(obj_id,'(10\\.\\d{4,5}\\/.+)\\z')
    dc_info<-fromJSON(paste0('https://api.datacite.org/works?query=',doi,'&rows=0'))
    return(head(dc_info$meta$`data-centers`,1)$title)
}

# %%
data_doi <- data %>%
    mutate(dc_doi = str_extract(obj_id,'(10\\.\\d{4,5}\\/.+)\\z'))
dois<-as.data.frame(unique(data_doi$dc_doi))
head(dois)
nrow(dois)
# Out:
#   unique(data_doi$dc_doi)
# 1 10.13140/RG.2.1.1350.3122
# 2 10.5061/dryad.dk385
# 3 10.7930/J0H12ZXG
# 4 10.5195/errs.2012.125
# 5 10.5256/f1000research.10763.d151064
# 6 10.5281/zenodo.193080
# [1] 7564

# %%
# dc_dois <- paste(tail(dois$`unique(data_doi$dc_doi)`,100), collapse=",")
# dc_dois

# %%
 dc_dois<-'10.13140/RG.2.1.1350.3122,10.5061/dryad.dk385,10.7930/J0H12ZXG,10.5195/errs.2012.125,10.5256/f1000research.10763.d151064,10.5281/zenodo.193080,10.18433/J3559N,10.5681/jcs.2012.033,10.3886/ICPSR24461.v4,10.3886/ICPSR04248.v3,10.5256/f1000research.10632.d150960,10.5281/zenodo.153937,10.3886/ICPSR30122.v5,10.5061/dryad.bn1gf,10.5061/dryad.320h5,10.5281/zenodo.167143,10.5256/f1000research.9667.d136816,10.5281/zenodo.54705,10.3205/000098,10.5256/f1000research.9740.d139661,10.5256/f1000research.9740.d139660,10.3205/psm000094,10.7490/f1000research.1112509.1,10.13140/RG.2.1.4929.1363,10.5281/zenodo.57900,10.5524/100076,10.6084/m9.figshare.1254958,10.5256/f1000research.10559.d148698,10.4119/UNIBI/jsse-v12-i1-1217,10.17863/CAM.195'
# dois_types<-fromJSON(paste0("https://api.datacite.org/works?ids=",dc_dois,"&rows=0"))
# dois_types$meta$`resource-types`

# %%
columns =c("dataset", "collection", "text", "software","audiovisual","image","interactive-resource","other","workflow")
zsd<-data.frame(matrix(0, ncol = length(columns), nrow = 1))
colnames(zsd) <- columns
class(zsd)
# Out:
# [1] "data.frame"

# %%
get_metacounts <- function(dc_dois){
#     print(dc_dois)
    x<- try(fromJSON(paste0("https://api.datacite.org/works?ids=",dc_dois,"&rows=0")))
    print(class(x))
    if(class(x) == 'list')
    {
        columns = (x$meta$`resource-types`$id)
        xsd<-data.frame(matrix(0, ncol = length(columns), nrow = 1))
        colnames(xsd) <- columns
        xsd <- rbind(xsd, x$meta$`resource-types`$count)
    }
    else{
        columns =c("dataset", "collection", "text", "software","audiovisual","image","interactive-resource","other","workflow")
        xsd<-data.frame(matrix(0, ncol = length(columns), nrow = 1))
        colnames(xsd) <- columns
        xsd <- xsd
    }
    
    return(xsd)
}

# get_metacounts(zsd, dc_dois)

# %%
lis <- dois$`unique(data_doi$dc_doi)`
n=100
xed<-paste((lis)[(n-89):n], collapse=",")

# %%
# lis <- dois$`unique(data_doi$dc_doi)`
# doisxx <- paste(head(lis,100), collapse=",")
# dataini <- fromJSON(paste0("https://api.datacite.org/works?ids=",doisxx,"&rows=0"))

# get_metacounts <- function(dc_dois){
#     x<- fromJSON(paste0("https://api.datacite.org/works?ids=",dc_dois,"&rows=0"))
# #     y<-x[order(title)]
#     print(x$meta$`resource-types`)
#     y <- t(zsd)
# }

# print(get_metacounts(xed))

for (n in seq(50, 7564, by = 50) ){
   dc_dois <- paste((lis)[(n-49):n], collapse=",")
   x<-(get_metacounts(dc_dois))
   zsd <- bind_rows(zsd, x)
}


# for (n in seq(90, 7564, by = 90) ){
#   dc_dois <- paste((lis)[(n-89):n], collapse=",")
#   print(try(
#       (fromJSON(
#           paste0("https://api.datacite.org/works?ids=",dc_dois,"&rows=0")
#        )
#       )$meta$`resource-types`$count
#   ))
# }

#[order(title)]
# https://stackoverflow.com/questions/26003574/r-dplyr-mutate-use-dynamic-variable-names
# Out:
# [1] "list"
#   text dataset software other
# 1    0       0        0     0
# 2   25      18        2     1
# [1] "list"
#   text dataset collection
# 1    0       0          0
# 2   21      17          1
# [1] "list"
#   text dataset collection other software
# 1    0       0          0     0        0
# 2   29       9          1     1        1
# [1] "list"
#   text software dataset
# 1    0        0       0
# 2   35        3       2
# [1] "list"
#   text dataset collection other software
# 1    0       0          0     0        0
# 2   26       9          1     1        1
# [1] "list"
#   text dataset software
# 1    0       0        0
# 2   21      17        1
# [1] "list"
#   text dataset software
# 1    0       0        0
# 2   23      15        1
# [1] "list"
#   dataset text software collection
# 1       0    0        0          0
# 2      23   16        3          1
# [1] "list"
#   text dataset software workflow
# 1    0       0        0        0
# 2   21      11        6        3
# [1] "list"
#   text dataset software collection other
# 1    0       0        0          0     0
# 2   19      13        4          1     1
# [1] "list"
#   dataset text collection
# 1       0    0          0
# 2      18   17          1
# [1] "list"
#   dataset text collection software
# 1       0    0          0        0
# 2      15   13          3        1
# [1] "list"
#   dataset text other collection interactive-resource software
# 1       0    0     0          0                    0        0
# 2      18   18     2          1                    1        1
# [1] "list"
#   dataset text collection other software
# 1       0    0          0     0        0
# 2      15   14          2     1        1
# [1] "list"
#   text dataset
# 1    0       0
# 2   18      12
# [1] "list"
#   text dataset software collection
# 1    0       0        0          0
# 2   19      16        2          1
# [1] "list"
#   dataset text software collection image
# 1       0    0        0          0     0
# 2      18   18        4          1     1
# [1] "list"
#   text dataset software
# 1    0       0        0
# 2   21      18        2
# [1] "list"
#   text dataset software collection image
# 1    0       0        0          0     0
# 2   23      11        3          2     2
# [1] "list"
#   text dataset collection
# 1    0       0          0
# 2   36       6          2
# [1] "list"
#   text dataset
# 1    0       0
# 2   37       8
# [1] "list"
#   text dataset collection software
# 1    0       0          0        0
# 2   30      11          2        1
# [1] "list"
#   dataset text software collection
# 1       0    0        0          0
# 2      29   10        4          1
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "list"
#   text dataset software collection image workflow
# 1    0       0        0          0     0        0
# 2   20      11        3          1     1        1
# [1] "list"
#   dataset text software collection
# 1       0    0        0          0
# 2      18   14        6          1
# [1] "list"
#   text dataset software collection
# 1    0       0        0          0
# 2   18      16        4          2
# [1] "list"
#   text dataset collection
# 1    0       0          0
# 2   21      20          1
# [1] "list"
#   text dataset software collection other interactive-resource
# 1    0       0        0          0     0                    0
# 2   16      14        5          2     2                    1
# [1] "list"
#   text dataset software
# 1    0       0        0
# 2   17      16        2
# [1] "list"
#   text dataset software
# 1    0       0        0
# 2   26       9        8
# [1] "list"
#   dataset text software
# 1       0    0        0
# 2      21   18        4
# [1] "list"
#   dataset text collection image physical-object
# 1       0    0          0     0               0
# 2      14   10          2     1               1
# [1] "list"
#   dataset text collection software
# 1       0    0          0        0
# 2      19    9          4        1
# [1] "list"
#   dataset text collection other software
# 1       0    0          0     0        0
# 2      17    6          5     2        2
# [1] "list"
#   dataset text collection other
# 1       0    0          0     0
# 2      22   10          1     1
# [1] "list"
#   dataset text collection other software
# 1       0    0          0     0        0
# 2      33    6          2     2        1
# [1] "list"
#   dataset software text collection
# 1       0        0    0          0
# 2      32        4    4          1
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "list"
#   dataset text software other
# 1       0    0        0     0
# 2      21   13        3     1
# [1] "list"
#   text dataset collection
# 1    0       0          0
# 2   22       3          1
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "list"
#   text dataset collection
# 1    0       0          0
# 2   22       4          1
# [1] "list"
#   text dataset
# 1    0       0
# 2   19      12
# [1] "list"
#   text dataset software collection
# 1    0       0        0          0
# 2   28       5        3          1
# [1] "list"
#   text dataset software collection
# 1    0       0        0          0
# 2   33       6        3          1
# [1] "list"
#   text dataset software
# 1    0       0        0
# 2   32       7        3
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "list"
#   text software dataset collection workflow
# 1    0        0       0          0        0
# 2   14       11       4          1        1
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "list"
#   text dataset software collection workflow
# 1    0       0        0          0        0
# 2   25       3        2          1        1
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "list"
#   text software collection dataset image
# 1    0        0          0       0     0
# 2   25        3          1       1     1
# [1] "list"
#   text software dataset
# 1    0        0       0
# 2   10        4       2
# [1] "list"
#   text dataset software
# 1    0       0        0
# 2   15       2        2
# [1] "list"
#   text dataset collection
# 1    0       0          0
# 2   43       3          1
# [1] "list"
#   text dataset
# 1    0       0
# 2   40       4
# [1] "list"
#   text dataset
# 1    0       0
# 2   40       5
# [1] "list"
#   text dataset collection
# 1    0       0          0
# 2   28      16          1
# [1] "list"
#   text dataset software other
# 1    0       0        0     0
# 2   21      18        2     1
# [1] "list"
#   text dataset image
# 1    0       0     0
# 2   42       3     1
# [1] "list"
#   text dataset software collection other
# 1    0       0        0          0     0
# 2   26      12        3          2     1
# [1] "list"
#   text dataset software collection
# 1    0       0        0          0
# 2   33      10        2          1
# [1] "list"
#   text dataset software
# 1    0       0        0
# 2   27      16        1
# [1] "list"
#   text dataset other collection software
# 1    0       0     0          0        0
# 2   24      17     2          1        1
# [1] "list"
#   text dataset other collection workflow
# 1    0       0     0          0        0
# 2   17      13     5          1        1
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "list"
#   text dataset
# 1    0       0
# 2   23      21
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "list"
#   text dataset
# 1    0       0
# 2   30      16
# [1] "list"
#   text dataset audiovisual software
# 1    0       0           0        0
# 2   26      19           2        2
# [1] "list"
#   dataset text software audiovisual collection
# 1       0    0        0           0          0
# 2      22   17        3           1          1
# [1] "list"
#   text dataset
# 1    0       0
# 2   21      17
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "list"
#   text dataset
# 1    0       0
# 2   32       5
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "list"
#   text dataset software collection workflow
# 1    0       0        0          0        0
# 2   28       8        3          1        1
# [1] "list"
#   text dataset software
# 1    0       0        0
# 2   33       8        3
# [1] "list"
#   text dataset software
# 1    0       0        0
# 2   33       9        3
# [1] "list"
#   text dataset software collection image
# 1    0       0        0          0     0
# 2   36       4        2          1     1
# [1] "list"
#   text dataset software
# 1    0       0        0
# 2   29       2        2
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "list"
#   text dataset software
# 1    0       0        0
# 2   28       7        1
# [1] "list"
#   text dataset software
# 1    0       0        0
# 2   24      12        1
# [1] "list"
#   text dataset collection software model
# 1    0       0          0        0     0
# 2   24       9          4        2     1
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "list"
#   text dataset collection other software
# 1    0       0          0     0        0
# 2   22       7          4     1        1
# [1] "list"
#   text dataset collection
# 1    0       0          0
# 2   23      12          1
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "list"
#   text dataset software collection
# 1    0       0        0          0
# 2   23      17        2          1
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "list"
#   text dataset software collection
# 1    0       0        0          0
# 2   23       7        2          1
# [1] "list"
#   text dataset software workflow
# 1    0       0        0        0
# 2   37       4        3        1
# [1] "list"
#   text dataset software workflow collection
# 1    0       0        0        0          0
# 2   27       5        2        2          1
# [1] "list"
#   text dataset software workflow
# 1    0       0        0        0
# 2   28       6        1        1
# [1] "list"
#   text dataset software image workflow
# 1    0       0        0     0        0
# 2   28       5        3     2        2
# [1] "list"
#   text dataset image software workflow
# 1    0       0     0        0        0
# 2   33       5     2        2        2
# [1] "list"
#   text dataset collection software
# 1    0       0          0        0
# 2   19      18          2        2
# [1] "list"
#   text dataset collection software
# 1    0       0          0        0
# 2   20      17          2        2
# [1] "list"
#   text dataset
# 1    0       0
# 2   34       9
# [1] "list"
#   text dataset software
# 1    0       0        0
# 2   38       6        1
# [1] "list"
#   text dataset collection
# 1    0       0          0
# 2   38       5          1
# [1] "list"
#   text dataset
# 1    0       0
# 2   41       2
# [1] "list"
#   text dataset software
# 1    0       0        0
# 2   40       3        1
# [1] "list"
#   text dataset software
# 1    0       0        0
# 2   42       2        1
# [1] "list"
#   text dataset
# 1    0       0
# 2   38       2
# [1] "list"
#   text dataset collection software
# 1    0       0          0        0
# 2   35       5          1        1
# [1] "list"
#   text dataset workflow collection software
# 1    0       0        0          0        0
# 2   28       6        3          1        1
# [1] "list"
#   text collection dataset software workflow
# 1    0          0       0        0        0
# 2   37          2       2        1        1
# [1] "list"
#   text dataset collection workflow
# 1    0       0          0        0
# 2   29      14          2        1
# [1] "list"
#   text dataset other software
# 1    0       0     0        0
# 2   33       6     2        2
# [1] "list"
#   text dataset other software
# 1    0       0     0        0
# 2   36       4     1        1
# [1] "list"
#   text dataset
# 1    0       0
# 2   34       9
# [1] "list"
#   text dataset software collection
# 1    0       0        0          0
# 2   24      10        2          1
# [1] "list"
#   text dataset collection
# 1    0       0          0
# 2   24       8          1
# [1] "list"
#   text dataset software collection
# 1    0       0        0          0
# 2   24      11        2          1
# [1] "list"
#   text dataset software
# 1    0       0        0
# 2   28      12        3
# [1] "list"
#   text dataset collection software
# 1    0       0          0        0
# 2   33       3          2        2
# [1] "list"
#   text dataset collection software interactive-resource
# 1    0       0          0        0                    0
# 2   28       7          5        3                    1
# [1] "list"
#   dataset collection software text
# 1       0          0        0    0
# 2      28         11        6    5
# [1] "list"
#   dataset collection text image software
# 1       0          0    0     0        0
# 2      32          9    4     1        1
# [1] "list"
#   dataset collection software text audiovisual
# 1       0          0        0    0           0
# 2      26         14        4    3           2
# [1] "list"
#   dataset collection text software audiovisual image other
# 1       0          0    0        0           0     0     0
# 2      27         12    3        2           1     1     1
# [1] "list"
#   dataset collection software text other audiovisual
# 1       0          0        0    0     0           0
# 2      32          7        4    3     2           1
# [1] "list"
#   dataset collection software text other
# 1       0          0        0    0     0
# 2      28         10        4    4     1
# [1] "list"
#   dataset collection text software image other
# 1       0          0    0        0     0     0
# 2      26         14    4        3     1     1
# [1] "list"
#   dataset collection text software
# 1       0          0    0        0
# 2      31          9    7        2
# [1] "list"
#   dataset collection text audiovisual software
# 1       0          0    0           0        0
# 2      25         12    7           1        1
# [1] "list"
#   dataset collection text software
# 1       0          0    0        0
# 2      30         11    5        3
# [1] "list"
#   dataset collection text software audiovisual other
# 1       0          0    0        0           0     0
# 2      22         13    5        2           1     1
# [1] "list"
#   dataset collection text software
# 1       0          0    0        0
# 2      30          8    4        3
# [1] "list"
#   dataset collection image software text
# 1       0          0     0        0    0
# 2      27         13     2        2    2
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "list"
#   dataset text collection software
# 1       0    0          0        0
# 2      22   14          5        1
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "list"
#   dataset text collection image software
# 1       0    0          0     0        0
# 2      26   16          1     1        1
# [1] "list"
#   dataset text collection software workflow
# 1       0    0          0        0        0
# 2      22   14          2        1        1
# [1] "list"
#   dataset text collection software other
# 1       0    0          0        0     0
# 2      22   13          4        4     1
# [1] "list"
#   text dataset collection image
# 1    0       0          0     0
# 2   21      14          3     1
# [1] "list"
#   dataset text collection other
# 1       0    0          0     0
# 2      20   15          2     2
# [1] "list"
#   text dataset collection software audiovisual
# 1    0       0          0        0           0
# 2   19      15          3        2           1
# [1] "list"
#   text dataset collection image
# 1    0       0          0     0
# 2   22      21          1     1
# [1] "list"
#   text dataset collection software
# 1    0       0          0        0
# 2   19      12          4        2
# [1] "list"
#   dataset text collection software image
# 1       0    0          0        0     0
# 2      15   15          3        3     1
# [1] "list"
#   text dataset collection other software
# 1    0       0          0     0        0
# 2   21      14          3     2        1
# [1] "list"
#   dataset text collection software other
# 1       0    0          0        0     0
# 2      23   13          3        3     1
# [1] "list"
#   text dataset collection software
# 1    0       0          0        0
# 2   32       8          1        1
# [1] "try-error"
#   dataset collection text software audiovisual image interactive-resource other
# 1       0          0    0        0           0     0                    0     0
#   workflow
# 1        0
# [1] "list"
#   text dataset software workflow
# 1    0       0        0        0
# 2   33       6        2        1
# [1] "list"
#   text dataset collection software
# 1    0       0          0        0
# 2   30       7          1        1

# %%
nrow(zsd)
zsd
# Out:
# [1] 285
#     dataset collection text software audiovisual image interactive-resource
# 1    0       0          0    0        0           0     0
# 2    0      NA          0    0       NA          NA    NA
# 3   18      NA         25    2       NA          NA    NA
# 4    0       0          0   NA       NA          NA    NA
# 5   17       1         21   NA       NA          NA    NA
# 6    0       0          0    0       NA          NA    NA
# 7    9       1         29    1       NA          NA    NA
# 8    0      NA          0    0       NA          NA    NA
# 9    2      NA         35    3       NA          NA    NA
# 10   0       0          0    0       NA          NA    NA
# 11   9       1         26    1       NA          NA    NA
# 12   0      NA          0    0       NA          NA    NA
# 13  17      NA         21    1       NA          NA    NA
# 14   0      NA          0    0       NA          NA    NA
# 15  15      NA         23    1       NA          NA    NA
# 16   0       0          0    0       NA          NA    NA
# 17  23       1         16    3       NA          NA    NA
# 18   0      NA          0    0       NA          NA    NA
# 19  11      NA         21    6       NA          NA    NA
# 20   0       0          0    0       NA          NA    NA
# 21  13       1         19    4       NA          NA    NA
# 22   0       0          0   NA       NA          NA    NA
# 23  18       1         17   NA       NA          NA    NA
# 24   0       0          0    0       NA          NA    NA
# 25  15       3         13    1       NA          NA    NA
# 26   0       0          0    0       NA          NA     0
# 27  18       1         18    1       NA          NA     1
# 28   0       0          0    0       NA          NA    NA
# 29  15       2         14    1       NA          NA    NA
# 30   0      NA          0   NA       NA          NA    NA
# ⋮   ⋮       ⋮          ⋮    ⋮        ⋮           ⋮     ⋮
# 256  0       0          0    0        0           0     0
# 257  0       0          0    0       NA           0    NA
# 258 26       1         16    1       NA           1    NA
# 259  0       0          0    0       NA          NA    NA
# 260 22       2         14    1       NA          NA    NA
# 261  0       0          0    0       NA          NA    NA
# 262 22       4         13    4       NA          NA    NA
# 263  0       0          0   NA       NA           0    NA
# 264 14       3         21   NA       NA           1    NA
# 265  0       0          0   NA       NA          NA    NA
# 266 20       2         15   NA       NA          NA    NA
# 267  0       0          0    0        0          NA    NA
# 268 15       3         19    2        1          NA    NA
# 269  0       0          0   NA       NA           0    NA
# 270 21       1         22   NA       NA           1    NA
# 271  0       0          0    0       NA          NA    NA
# 272 12       4         19    2       NA          NA    NA
# 273  0       0          0    0       NA           0    NA
# 274 15       3         15    3       NA           1    NA
# 275  0       0          0    0       NA          NA    NA
# 276 14       3         21    1       NA          NA    NA
# 277  0       0          0    0       NA          NA    NA
# 278 23       3         13    3       NA          NA    NA
# 279  0       0          0    0       NA          NA    NA
# 280  8       1         32    1       NA          NA    NA
# 281  0       0          0    0        0           0     0
# 282  0      NA          0    0       NA          NA    NA
# 283  6      NA         33    2       NA          NA    NA
# 284  0       0          0    0       NA          NA    NA
# 285  7       1         30    1       NA          NA    NA
#     other workflow physical-object model
# 1    0     0       NA              NA
# 2    0    NA       NA              NA
# 3    1    NA       NA              NA
# 4   NA    NA       NA              NA
# 5   NA    NA       NA              NA
# 6    0    NA       NA              NA
# 7    1    NA       NA              NA
# 8   NA    NA       NA              NA
# 9   NA    NA       NA              NA
# 10   0    NA       NA              NA
# 11   1    NA       NA              NA
# 12  NA    NA       NA              NA
# 13  NA    NA       NA              NA
# 14  NA    NA       NA              NA
# 15  NA    NA       NA              NA
# 16  NA    NA       NA              NA
# 17  NA    NA       NA              NA
# 18  NA     0       NA              NA
# 19  NA     3       NA              NA
# 20   0    NA       NA              NA
# 21   1    NA       NA              NA
# 22  NA    NA       NA              NA
# 23  NA    NA       NA              NA
# 24  NA    NA       NA              NA
# 25  NA    NA       NA              NA
# 26   0    NA       NA              NA
# 27   2    NA       NA              NA
# 28   0    NA       NA              NA
# 29   1    NA       NA              NA
# 30  NA    NA       NA              NA
# ⋮   ⋮     ⋮        ⋮               ⋮
# 256  0     0       NA              NA
# 257 NA    NA       NA              NA
# 258 NA    NA       NA              NA
# 259 NA     0       NA              NA
# 260 NA     1       NA              NA
# 261  0    NA       NA              NA
# 262  1    NA       NA              NA
# 263 NA    NA       NA              NA
# 264 NA    NA       NA              NA
# 265  0    NA       NA              NA
# 266  2    NA       NA              NA
# 267 NA    NA       NA              NA
# 268 NA    NA       NA              NA
# 269 NA    NA       NA              NA
# 270 NA    NA       NA              NA
# 271 NA    NA       NA              NA
# 272 NA    NA       NA              NA
# 273 NA    NA       NA              NA
# 274 NA    NA       NA              NA
# 275  0    NA       NA              NA
# 276  2    NA       NA              NA
# 277  0    NA       NA              NA
# 278  1    NA       NA              NA
# 279 NA    NA       NA              NA
# 280 NA    NA       NA              NA
# 281  0     0       NA              NA
# 282 NA     0       NA              NA
# 283 NA     1       NA              NA
# 284 NA    NA       NA              NA
# 285 NA    NA       NA              NA

# %%
zsd[is.na(zsd)] <- 0
nrow(zsd)
summ<-colSums(zsd)
summ
# Out:
# [1] 285
#              dataset           collection                 text
#                 1777                  272                 2988
#             software          audiovisual                image
#                  246                   10                   21
# interactive-resource                other             workflow
#                    3                   40                   23
#      physical-object                model
#                    1                    1

# %%
yyy<-data.frame(round((summ/7564),4)*100)
colnames(yyy) <- c("counts")
yyy
# counts <- table(yyy$counts)
# g <- ggplot(yyy, aes(counts))
# Out:
#                      counts
# dataset              23.49
# collection            3.60
# text                 39.50
# software              3.25
# audiovisual           0.13
# image                 0.28
# interactive-resource  0.04
# other                 0.53
# workflow              0.30
# physical-object       0.01
# model                 0.01

# %%
# Out:
# Error in eval(expr, envir, enclos): could not find function "ggplot"
# Traceback:

# %%
save(summ,file="../data/17072017_Mugging_Crossref_Datacite_links_dcDois_out.Rda")

# %%
get_types <- function(dc_dois){
#     print(dc_dois)
    x<- try(fromJSON(paste0("https://api.datacite.org/works?ids=",dc_dois,"&rows=0")))
    print(class(x))
    if(class(x) == 'list')
    {
        xsd <-select(x$data$attributes, doi, `resource-type-id`,`data-center-id` )
#         columns = (y)
#         xsd<-data.frame(matrix(0, ncol = length(columns), nrow = 1))
#         colnames(xsd) <- columns
#         xsd <- rbind(xsd, y)
        
    }
    else{
        xsd<-data.frame(matrix("fd", ncol = 3, nrow = 1))
        colnames(xsd) <- c("doi" ,"resource-type-id", "data-center-id")
        print(xsd)
        xsd <- xsd
    }
    
    return(xsd)
}

# %%
#  dc_dois<-'10.13140/RG.2.1.1350.3122,10.5061/dryad.dk385,10.7930/J0H12ZXG,10.5195/errs.2012.125,10.5256/f1000research.10763.d151064,10.5281/zenodo.193080,10.18433/J3559N,10.5681/jcs.2012.033,10.3886/ICPSR24461.v4,10.3886/ICPSR04248.v3,10.5256/f1000research.10632.d150960,10.5281/zenodo.153937,10.3886/ICPSR30122.v5,10.5061/dryad.bn1gf,10.5061/dryad.320h5,10.5281/zenodo.167143,10.5256/f1000research.9667.d136816,10.5281/zenodo.54705,10.3205/000098,10.5256/f1000research.9740.d139661,10.5256/f1000research.9740.d139660,10.3205/psm000094,10.7490/f1000research.1112509.1,10.13140/RG.2.1.4929.1363,10.5281/zenodo.57900,10.5524/100076,10.6084/m9.figshare.1254958,10.5256/f1000research.10559.d148698,10.4119/UNIBI/jsse-v12-i1-1217,10.17863/CAM.195'
# get_types(dc_dois)

# %%
dois_dc_type<-data.frame(matrix(NA, ncol = 3, nrow = 1))
colnames(dois_dc_type) <- c("doi" ,"resource-type-id", "data-center-id")
dois_dc_type <- dois_dc_type

for (n in seq(10, 7564, by = 10) ){
   dc_dois <- paste((lis)[(n-9):n], collapse=",")
   x<-(get_types(dc_dois))
   dois_dc_type <- bind_rows(dois_dc_type, x)
}
# Out:
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "try-error"
#   doi resource-type-id data-center-id
# 1  fd               fd             fd
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"
# [1] "list"

# %%
nrow(dois_dc_type)
# Out:
# [1] 6717

# %%
data_doix <- data %>%
    mutate(doi = str_extract(obj_id,'(10\\.\\d{4,5}\\/.+)\\z'))

# %%
data_doix <- data_doix %>% 
#     rowwise() %>% 
    left_join(dois_dc_type)
head(data_doix)
# Out:
# Joining, by = "doi"
#   license
# 1 https://doi.org/10.13003/CED-terms-of-use
# 2 https://doi.org/10.13003/CED-terms-of-use
# 3 https://doi.org/10.13003/CED-terms-of-use
# 4 https://doi.org/10.13003/CED-terms-of-use
# 5 https://doi.org/10.13003/CED-terms-of-use
# 6 https://doi.org/10.13003/CED-terms-of-use
#   obj_id
# 1 https://doi.org/10.13140/RG.2.1.1350.3122
# 2 https://doi.org/10.5061/dryad.dk385
# 3 https://doi.org/10.7930/J0H12ZXG
# 4 https://doi.org/10.5195/errs.2012.125
# 5 https://doi.org/10.5256/f1000research.10763.d151064
# 6 https://doi.org/10.5281/zenodo.193080
#   source_token                         occurred_at
# 1 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2017-04-01
# 2 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2017-02-13
# 3 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2017-02-13
# 4 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2016-11-21
# 5 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2017-02-10
# 6 8676e950-8ac5-4074-8ac3-c0a18ada7e99 2016-12-20
#   subj_id
# 1 https://doi.org/10.1109/LRA.2017.2651945
# 2 https://doi.org/10.1111/pala.12283
# 3 https://doi.org/10.1007/s10669-017-9631-z
# 4 https://doi.org/10.1080/14702436.2016.1256209
# 5 https://doi.org/10.12688/f1000research.10763.1
# 6 https://doi.org/10.12688/f1000research.10426.1
#   id
# 1 26eb9df3-c841-48c2-b3f8-239c0bf91506
# 2 d53dd280-221e-48f9-bbf8-d48aba12d818
# 3 a750e5b8-3bc6-4054-a321-949c7ad330c5
# 4 f007f43b-7649-4b43-9224-3729b2536f65
# 5 46f3df4f-74c0-42f2-a76d-b108f86d768b
# 6 d871bfce-69ce-4437-be74-b8584ef3b0ec
#   terms                                     message_action source_id timestamp
# 1 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
# 2 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
# 3 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
# 4 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
# 5 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
# 6 https://doi.org/10.13003/CED-terms-of-use create         crossref  2017-05-19
#   relation_type_id obj_prefix subj_prefix unique(data$obj_prefix)
# 1 references       10.13140   10.1109     10.13140
# 2 references       10.5061    10.1111     10.5061
# 3 references       10.7930    10.1007     10.7930
# 4 references       10.5195    10.1080     10.5195
# 5 references       10.5256    10.12688    10.5256
# 6 references       10.5281    10.12688    10.5281
#   obj_dc                                   unique(data$subj_prefix)
# 1 ResearchGate                             10.1109
# 2 Dryad                                    10.1111
# 3 U.S. Global Change Research Program/UCAR 10.1007
# 4 University of Pittsburgh                 10.1080
# 5 Faculty of 1000 Research Ltd             10.12688
# 6 ZENODO - Research. Shared.               10.12688
#   subj_dc
# 1 Institute of Electrical and Electronics Engineers (IEEE)
# 2 Wiley-Blackwell
# 3 Springer Nature
# 4 Informa UK Limited
# 5 F1000 Research, Ltd.
# 6 F1000 Research, Ltd.
#   doi                                 resource-type-id data-center-id
# 1 10.13140/RG.2.1.1350.3122           NA               rg.rg
# 2 10.5061/dryad.dk385                 NA               NA
# 3 10.7930/J0H12ZXG                    text             cdl.usgcrp
# 4 10.5195/errs.2012.125               NA               NA
# 5 10.5256/f1000research.10763.d151064 NA               NA
# 6 10.5281/zenodo.193080               NA               NA

# %%
save(data_doix,file="../data/17072017_Mugging_Crossref_Datacite_links_typeDois_out.Rda")

# %%
data_doix %>%
 filter(doi == "10.5256/f1000research.10763.d151064" )
# Out:
#    doi resource-type-id data-center-id
# 1  fd  fd               fd
# 2  fd  fd               fd
# 3  fd  fd               fd
# 4  fd  fd               fd
# 5  fd  fd               fd
# 6  fd  fd               fd
# 7  fd  fd               fd
# 8  fd  fd               fd
# 9  fd  fd               fd
# 10 fd  fd               fd
# 11 fd  fd               fd
# 12 fd  fd               fd
# 13 fd  fd               fd
# 14 fd  fd               fd
# 15 fd  fd               fd
# 16 fd  fd               fd
# 17 fd  fd               fd
# 18 fd  fd               fd
# 19 fd  fd               fd
# 20 fd  fd               fd
# 21 fd  fd               fd

# %%
data.frame(lis)  %>%
 filter(lis == "10.5256/f1000research.10763.d151064")
# Out:
#   lis
# 1 10.5256/f1000research.10763.d151064

# %%
# Out:
#      lis
# 1    10.13140/RG.2.1.1350.3122
# 2    10.5061/dryad.dk385
# 3    10.7930/J0H12ZXG
# 4    10.5195/errs.2012.125
# 5    10.5256/f1000research.10763.d151064
# 6    10.5281/zenodo.193080
# 7    10.18433/J3559N
# 8    10.5681/jcs.2012.033
# 9    10.3886/ICPSR24461.v4
# 10   10.3886/ICPSR04248.v3
# 11   10.5256/f1000research.10632.d150960
# 12   10.5281/zenodo.153937
# 13   10.3886/ICPSR30122.v5
# 14   10.5061/dryad.bn1gf
# 15   10.5061/dryad.320h5
# 16   10.5281/zenodo.167143
# 17   10.5256/f1000research.9667.d136816
# 18   10.5281/zenodo.54705
# 19   10.3205/000098
# 20   10.5256/f1000research.9740.d139661
# 21   10.5256/f1000research.9740.d139660
# 22   10.3205/psm000094
# 23   10.7490/f1000research.1112509.1
# 24   10.13140/RG.2.1.4929.1363
# 25   10.5281/zenodo.57900
# 26   10.5524/100076
# 27   10.6084/m9.figshare.1254958
# 28   10.5256/f1000research.10559.d148698
# 29   10.4119/UNIBI/jsse-v12-i1-1217
# 30   10.17863/CAM.195
# ⋮    ⋮
# 7535 10.5281/zenodo.16341
# 7536 10.13140/RG.2.1.3853.0323
# 7537 10.5885/44985SL-8F203FD3ACCD4138
# 7538 10.7287/peerj.preprints.539v1
# 7539 10.1285/i1825229Xv1n3p3
# 7540 10.15129/256283ed-aed3-4534-a385-43df18fd63a5
# 7541 10.7916/D88K7916
# 7542 10.18419/opus-2286
# 7543 10.3205/dgkh000146
# 7544 10.3205/000185
# 7545 10.14279/tuj.eceasst.37.512.544
# 7546 10.5681/bi.2013.016
# 7547 10.5681/apb.2012.002
# 7548 10.5061/dryad.34r55
# 7549 10.14283/jfa.2016.80
# 7550 10.5681/bi.2011.021
# 7551 10.5281/zenodo.27239
# 7552 10.5681/apb.2013.031
# 7553 10.11588/ai.2006.1&2.11115
# 7554 10.5681/hpp.2014.004
# 7555 10.7916/D83F4MR8
# 7556 10.18438/B8S30X
# 7557 10.5065/D6FB50XD
# 7558 10.5284/1000227
# 7559 10.5284/10000264
# 7560 10.7916/D87080M9
# 7561 10.6092/unibo/amsacta/2596
# 7562 10.5195/ERRS.2016.383
# 7563 10.5681/bi.2011.028
# 7564 10.20360/G2DW2X
